# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# Load the dataset (train.csv downloaded from Kaggle)
df = pd.read_csv('/content/drive/MyDrive/task2/titanic.zip (Unzipped Files)/train.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
import pandas as pd

# Load the dataset (train.csv downloaded from Kaggle)
df = pd.read_csv('/content/drive/MyDrive/task2/titanic.zip (Unzipped Files)/train.csv')
df.head()
# Summary of dataset
df.info()
df.describe()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# ...

# %%
import pandas as pd

# Load the dataset (train.csv downloaded from Kaggle)
df = pd.read_csv('/content/drive/MyDrive/task2/titanic.zip (Unzipped Files)/train.csv')
df.head()
# Summary of dataset
df.info()
df.describe()
df.isnull().sum()
# Fill 'Age' with median
df['Age'].fillna(df['Age'].median(), inplace=True)

# Drop 'Cabin' (too many missing values)
df.drop('Cabin', axis=1, inplace=True)

# Fill 'Embarked' with most frequent value
df['Embarked'].fillna(df['Embarked'].mode()[0], inplace=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# /tmp/ipython-input-4-1954760500.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
import pandas as pd

# Load the dataset (train.csv downloaded from Kaggle)
df = pd.read_csv('/content/drive/MyDrive/task2/titanic.zip (Unzipped Files)/train.csv')
df.head()
# Summary of dataset
df.info()
df.describe()
df.isnull().sum()
# Fill 'Age' with median
df['Age'].fillna(df['Age'].median(), inplace=True)

# Drop 'Cabin' (too many missing values)
df.drop('Cabin', axis=1, inplace=True)

# Fill 'Embarked' with most frequent value
df['Embarked'].fillna(df['Embarked'].mode()[0], inplace=True)
df.drop(['PassengerId', 'Name', 'Ticket'], axis=1, inplace=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# /tmp/ipython-input-5-388909148.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Survival Count
sns.countplot(data=df, x='Survived')
plt.title("Survival Count")
plt.show()

# Percentage
survival_rate = df['Survived'].value_counts(normalize=True) * 100
print(survival_rate)
# Out:
# Survived
# 0    61.616162
# 1    38.383838
# Name: proportion, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Survival Count
sns.countplot(data=df, x='Survived')
plt.title("Survival Count")
plt.show()

# Percentage
survival_rate = df['Survived'].value_counts(normalize=True) * 100
print(survival_rate)
sns.countplot(data=df, x='Sex', hue='Survived')
plt.title("Survival by Gender")
plt.xticks([0,1], ['Male', 'Female'])
plt.show()
# Out:
# Survived
# 0    61.616162
# 1    38.383838
# Name: proportion, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Survival Count
sns.countplot(data=df, x='Survived')
plt.title("Survival Count")
plt.show()

# Percentage
survival_rate = df['Survived'].value_counts(normalize=True) * 100
print(survival_rate)
sns.countplot(data=df, x='Sex', hue='Survived')
plt.title("Survival by Gender")
plt.xticks([0,1], ['Male', 'Female'])
plt.show()
sns.countplot(data=df, x='Pclass', hue='Survived')
plt.title("Survival by Passenger Class")
plt.show()
# Out:
# Survived
# 0    61.616162
# 1    38.383838
# Name: proportion, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Survival Count
sns.countplot(data=df, x='Survived')
plt.title("Survival Count")
plt.show()

# Percentage
survival_rate = df['Survived'].value_counts(normalize=True) * 100
print(survival_rate)
sns.countplot(data=df, x='Sex', hue='Survived')
plt.title("Survival by Gender")
plt.xticks([0,1], ['Male', 'Female'])
plt.show()
sns.countplot(data=df, x='Pclass', hue='Survived')
plt.title("Survival by Passenger Class")
plt.show()
sns.histplot(data=df, x='Age', bins=30, kde=True)
plt.title("Age Distribution")
plt.show()
# Out:
# Survived
# 0    61.616162
# 1    38.383838
# Name: proportion, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Survival Count
sns.countplot(data=df, x='Survived')
plt.title("Survival Count")
plt.show()

# Percentage
survival_rate = df['Survived'].value_counts(normalize=True) * 100
print(survival_rate)
sns.countplot(data=df, x='Sex', hue='Survived')
plt.title("Survival by Gender")
plt.xticks([0,1], ['Male', 'Female'])
plt.show()
sns.countplot(data=df, x='Pclass', hue='Survived')
plt.title("Survival by Passenger Class")
plt.show()
sns.histplot(data=df, x='Age', bins=30, kde=True)
plt.title("Age Distribution")
plt.show()
sns.histplot(data=df, x='Age', bins=30, hue='Survived', multiple='stack')
plt.title("Survival by Age")
plt.show()
# Out:
# Survived
# 0    61.616162
# 1    38.383838
# Name: proportion, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Survival Count
sns.countplot(data=df, x='Survived')
plt.title("Survival Count")
plt.show()

# Percentage
survival_rate = df['Survived'].value_counts(normalize=True) * 100
print(survival_rate)
sns.countplot(data=df, x='Sex', hue='Survived')
plt.title("Survival by Gender")
plt.xticks([0,1], ['Male', 'Female'])
plt.show()
sns.countplot(data=df, x='Pclass', hue='Survived')
plt.title("Survival by Passenger Class")
plt.show()
sns.histplot(data=df, x='Age', bins=30, kde=True)
plt.title("Age Distribution")
plt.show()
sns.histplot(data=df, x='Age', bins=30, hue='Survived', multiple='stack')
plt.title("Survival by Age")
plt.show()
corr = df.select_dtypes(include=['number']).corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title("Correlation Matrix")
plt.show()
# Out:
# Survived
# 0    61.616162
# 1    38.383838
# Name: proportion, dtype: float64
